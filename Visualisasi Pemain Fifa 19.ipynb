# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('data_fifa.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club      ...       Composure Marking StandingTackle  \
# 0         FC Barcelona      ...            96.0    33.0           28.0
# 1             Juventus      ...            95.0    28.0           31.0
# 2  Paris Saint-Germain      ...            94.0    27.0           24.0
# 3    Manchester United      ...            68.0    15.0           21.0
# 4      Manchester City      ...            88.0    68.0           58.0
#
#    SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 0           26.0      6.0        11.0       15.0           14.0        8.0
# 1           23.0      7.0        11.0       15.0           14.0       11.0
# 2           33.0      9.0         9.0       15.0           15.0       11.0
# 3           13.0     90.0        85.0       87.0           88.0       94.0
# 4           51.0     15.0        13.0        5.0           10.0       13.0
#
#   Release Clause
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#
# [5 rows x 89 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# Body Type                   18159 non-null object
# Real Face                   18159 non-null object
# Position                    18147 non-null object
# Jersey Number               18147 non-null float64
# Joined                      16654 non-null object
# Loaned From                 1264 non-null object
# Contract Valid Until        17918 non-null object
# Height                      18159 non-null object
# Weight                      18159 non-null object
# LS                          16122 non-null object
# ST                          16122 non-null object
# RS                          16122 non-null object
# LW                          16122 non-null object
# LF                          16122 non-null object
# CF                          16122 non-null object
# RF                          16122 non-null object
# RW                          16122 non-null object
# LAM                         16122 non-null object
# CAM                         16122 non-null object
# RAM                         16122 non-null object
# LM                          16122 non-null object
# LCM                         16122 non-null object
# CM                          16122 non-null object
# RCM                         16122 non-null object
# RM                          16122 non-null object
# LWB                         16122 non-null object
# LDM                         16122 non-null object
# CDM                         16122 non-null object
# RDM                         16122 non-null object
# RWB                         16122 non-null object
# LB                          16122 non-null object
# LCB                         16122 non-null object
# CB                          16122 non-null object
# RCB                         16122 non-null object
# RB                          16122 non-null object
# Crossing                    18159 non-null float64
# Finishing                   18159 non-null float64
# HeadingAccuracy             18159 non-null float64
# ShortPassing                18159 non-null float64
# Volleys                     18159 non-null float64
# Dribbling                   18159 non-null float64
# Curve                       18159 non-null float64
# FKAccuracy                  18159 non-null float64
# LongPassing                 18159 non-null float64
# BallControl                 18159 non-null float64
# Acceleration                18159 non-null float64
# SprintSpeed                 18159 non-null float64
# Agility                     18159 non-null float64
# Reactions                   18159 non-null float64
# Balance                     18159 non-null float64
# ShotPower                   18159 non-null float64
# Jumping                     18159 non-null float64
# Stamina                     18159 non-null float64
# Strength                    18159 non-null float64
# LongShots                   18159 non-null float64
# Aggression                  18159 non-null float64
# Interceptions               18159 non-null float64
# Positioning                 18159 non-null float64
# Vision                      18159 non-null float64
# Penalties                   18159 non-null float64
# Composure                   18159 non-null float64
# Marking                     18159 non-null float64
# StandingTackle              18159 non-null float64
# SlidingTackle               18159 non-null float64
# GKDiving                    18159 non-null float64
# GKHandling                  18159 non-null float64
# GKKicking                   18159 non-null float64
# GKPositioning               18159 non-null float64
# GKReflexes                  18159 non-null float64
# Release Clause              16643 non-null object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(1, figsize = (15,6))
data['Age'].plot(kind = 'hist', bins = 50)
plt.title('Plot Histogram Umur Pemain')
plt.show()

# %%
data.sort_values(by = 'Age' , ascending = False) [['Name','Club','Nationality','Overall','Age','Stamina']].head(5)
# Out:
#                 Name                          Club        Nationality  \
# 4741        O. Pérez                       Pachuca             Mexico
# 18183  K. Pilkington              Cambridge United            England
# 17726      T. Warner            Accrington Stanley  Trinidad & Tobago
# 10545    S. Narazaki                Nagoya Grampus              Japan
# 7225        C. Muñoz  CD Universidad de Concepción          Argentina
#
#        Overall  Age  Stamina
# 4741        71   45     41.0
# 18183       48   44     22.0
# 17726       53   44     25.0
# 10545       65   42     40.0
# 7225        68   41     29.0

# %%
data.sort_values(by = 'Age', ascending = True) [['Name','Club','Nationality','Overall','Age','Stamina']].head(5)
# Out:
#               Name             Club Nationality  Overall  Age  Stamina
# 18206    G. Nugent  Tranmere Rovers     England       46   16     47.0
# 17743    J. Olstad  Sarpsborg 08 FF      Norway       52   16     50.0
# 13293  H. Massengo        AS Monaco      France       62   16     62.0
# 16081  J. Italiano      Perth Glory   Australia       58   16     57.0
# 18166     N. Ayéva        Örebro SK      Sweden       48   16     58.0

# %%
import seaborn as sns

# %%
kordata = ['Age', 'Stamina' , 'Strength' , 'Acceleration','SprintSpeed' , 'Agility' , 'Jumping' ,
       'Vision','Reactions']

# %%
sns.heatmap(data[kordata].corr(),linewidths=.5,annot=True,cmap='RdYlGn')
fig=plt.gcf()
fig.set_size_inches(15,8)
plt.show()

# %%
best_dict = {}
for club in data['Club'].unique():
    overall_rating = data['Overall'][data['Club'] == club].sum()
    best_dict[club] = overall_rating

# %%
best_dict
# Out:
# {'FC Barcelona': 2575,
#  'Juventus': 2057,
#  'Paris Saint-Germain': 2323,
#  'Manchester United': 2549,
#  'Manchester City': 2532,
#  'Chelsea': 2534,
#  'Real Madrid': 2582,
#  'Atlético Madrid': 2477,
#  'FC Bayern München': 2233,
#  'Tottenham Hotspur': 2531,
#  'Liverpool': 2508,
#  'Napoli': 2000,
#  'Arsenal': 2481,
#  'Milan': 2108,
#  'Inter': 1914,
#  'Lazio': 2414,
#  'Borussia Dortmund': 2486,
#  'Vissel Kobe': 1883,
#  'Olympique Lyonnais': 2131,
#  'Roma': 2013,
#  'Valencia CF': 2465,
#  'Guangzhou Evergrande Taobao FC': 1868,
#  'FC Porto': 2147,
#  'FC Schalke 04': 2155,
#  'Beşiktaş JK': 2032,
#  'LA Galaxy': 1706,
#  'Sporting CP': 2284,
#  'Real Betis': 2030,
#  'Olympique de Marseille': 2141,
#  'RC Celta': 2391,
#  'Bayer 04 Leverkusen': 1971,
#  'Real Sociedad': 2251,
#  'Villarreal CF': 2379,
#  'Sevilla FC': 2256,
#  'SL Benfica': 2156,
#  'AS Saint-Étienne': 1701,
#  'AS Monaco': 2407,
#  'Leicester City': 2363,
#  'Atalanta': 1742,
#  'Grêmio': 1467,
#  'Atlético Mineiro': 1469,
#  'RB Leipzig': 2047,
#  'Ajax': 2209,
#  'Dalian YiFang FC': 1690,
#  'Everton': 2446,
#  'West Ham United': 2339,
#  '1. FC Köln': 1982,
#  'TSG 1899 Hoffenheim': 2410,
#  'Shanghai SIPG FC': 1777,
#  'OGC Nice': 2030,
#  'Al Nassr': 1900,
#  'Wolverhampton Wanderers': 2271,
#  'Borussia Mönchengladbach': 2196,
#  'Hertha BSC': 2281,
#  'SV Werder Bremen': 2300,
#  'Cruzeiro': 1448,
#  'Athletic Club de Bilbao': 2288,
#  'Torino': 1906,
#  'Medipol Başakşehir FK': 1982,
#  'Beijing Sinobo Guoan FC': 1816,
#  'Crystal Palace': 2261,
#  'PFC CSKA Moscow': 1926,
#  'VfL Wolfsburg': 2324,
#  'Shakhtar Donetsk': 2039,
#  'Toronto FC': 1873,
#  'Lokomotiv Moscow': 2025,
#  'Sassuolo': 1952,
#  'New York City FC': 1743,
#  'Fluminense': 1442,
#  'PSV': 2153,
#  'Levante UD': 2309,
#  'Fulham': 2226,
#  'Watford': 2098,
#  'Atlanta United': 1933,
#  'Montpellier HSC': 1966,
#  'Galatasaray SK': 2122,
#  'Fenerbahçe SK': 2196,
#  'SD Eibar': 2123,
#  'Los Angeles FC': 1694,
#  'Sampdoria': 1963,
#  'Al Hilal': 2059,
#  'VfB Stuttgart': 1947,
#  'SC Braga': 2095,
#  'River Plate': 1780,
#  'Deportivo Alavés': 1987,
#  nan: 0,
#  'Eintracht Frankfurt': 2417,
#  'Girona FC': 2075,
#  'Guangzhou R&F; FC': 1697,
#  'Burnley': 2335,
#  'Stoke City': 2112,
#  'Southampton': 2357,
#  'Tianjin Quanjian FC': 1574,
#  'Getafe CF': 2044,
#  'Beijing Renhe FC': 1702,
#  'Montreal Impact': 1915,
#  'Chievo Verona': 1992,
#  'Genoa': 1948,
#  'Portland Timbers': 1991,
#  'Tigres U.A.N.L.': 2085,
#  'RCD Espanyol': 2074,
#  'Hebei China Fortune FC': 1796,
#  'Cagliari': 1761,
#  'Chicago Fire': 1520,
#  'DC United': 1892,
#  'Sagan Tosu': 1927,
#  'Dynamo Kyiv': 1998,
#  'Santos': 1404,
#  'Internacional': 1465,
#  'América FC (Minas Gerais)': 1403,
#  'Independiente': 2004,
#  'Boca Juniors': 1982,
#  'Cruz Azul': 1744,
#  '1. FSV Mainz 05': 2267,
#  'Bournemouth': 2236,
#  'Spartak Moscow': 1976,
#  'Racing Club': 1984,
#  'FC Augsburg': 2172,
#  'Fiorentina': 1748,
#  'FC Nantes': 2261,
#  'Feyenoord': 1977,
#  'Club Brugge KV': 2007,
#  'Brighton & Hove Albion': 2270,
#  'Al Ahli': 1971,
#  'Jiangsu Suning FC': 1702,
#  'SC Freiburg': 2106,
#  'PAOK': 1956,
#  'Stade Rennais FC': 1931,
#  'Trabzonspor': 1944,
#  'SPAL': 1916,
#  'Portimonense SC': 1869,
#  'Olympiacos CFP': 2030,
#  'Club Atlético Huracán': 1894,
#  'Kasimpaşa SK': 1560,
#  'Newcastle United': 2339,
#  'Frosinone': 2298,
#  'Querétaro': 1991,
#  'KRC Genk': 1781,
#  'Hannover 96': 2054,
#  'Stade Malherbe Caen': 1941,
#  'Godoy Cruz': 1811,
#  'Toulouse Football Club': 2174,
#  'RSC Anderlecht': 1970,
#  'Huddersfield Town': 2204,
#  'CD Tondela': 1686,
#  'Seattle Sounders FC': 1827,
#  'Hamburger SV': 2054,
#  'FC Red Bull Salzburg': 1873,
#  'Rio Ave FC': 1931,
#  'FC Girondins de Bordeaux': 2216,
#  'Melbourne Victory': 1350,
#  'Parma': 2033,
#  'FC Basel 1893': 1857,
#  'Al Wehda': 1940,
#  'BSC Young Boys': 1601,
#  'KAA Gent': 1957,
#  'Al Ittihad': 1986,
#  'Standard de Liège': 1973,
#  'Shanghai Greenland Shenhua FC': 1765,
#  'Colo-Colo': 1910,
#  'Junior FC': 1896,
#  'West Bromwich Albion': 2086,
#  'RC Strasbourg Alsace': 1935,
#  'Göztepe SK': 1916,
#  'Deportivo Cali': 1903,
#  'Deportivo Toluca': 1884,
#  'Bologna': 2043,
#  'Nagoya Grampus': 1693,
#  'Amiens SC': 2004,
#  'Changchun Yatai FC': 1722,
#  'Club Atlético Lanús': 1905,
#  'Botafogo': 1426,
#  'Club América': 2081,
#  'Udinese': 2154,
#  'Real Valladolid CF': 2093,
#  'CD Leganés': 2355,
#  'Club Atlético Banfield': 1799,
#  'Celtic': 2007,
#  'Vitória Guimarães': 2170,
#  'FC København': 1573,
#  'UD Las Palmas': 2030,
#  'Deportivo de La Coruña': 2121,
#  'Universidad Católica': 1854,
#  'San Lorenzo de Almagro': 1931,
#  'Rayo Vallecano': 2304,
#  'Monterrey': 1799,
#  'Columbus Crew SC': 1772,
#  'MKE Ankaragücü': 2004,
#  'Guizhou Hengfeng FC': 1739,
#  'Swansea City': 2053,
#  'Tianjin TEDA FC': 1660,
#  'Chongqing Dangdai Lifan FC SWM Team': 1704,
#  'AEK Athens': 1966,
#  'Al Taawoun': 1808,
#  'Melbourne City FC': 1583,
#  'En Avant de Guingamp': 1782,
#  'Akhisar Belediyespor': 1797,
#  'Foggia': 1743,
#  'LOSC Lille': 1741,
#  '1. FC Nürnberg': 1996,
#  'Clube Sport Marítimo': 1611,
#  'Real Sporting de Gijón': 2054,
#  'BB Erzurumspor': 1627,
#  'Shandong Luneng TaiShan FC': 1704,
#  'Club Atlético Colón': 1898,
#  'Bahia': 1402,
#  'Once Caldas': 1823,
#  'FC Groningen': 1698,
#  'Angers SCO': 2100,
#  'Paraná': 1374,
#  'Antalyaspor': 2020,
#  'Minnesota United FC': 1980,
#  'Club León': 1998,
#  'Empoli': 2255,
#  'VVV-Venlo': 1680,
#  'Leeds United': 2026,
#  'Viktoria Plzeň': 1666,
#  'Alanyaspor': 2040,
#  'Atlético Paranaense': 1392,
#  'Derby County': 2077,
#  'Kawasaki Frontale': 1959,
#  'Cardiff City': 2250,
#  'Aston Villa': 2056,
#  'Guadalajara': 1968,
#  'Dijon FCO': 1829,
#  'Santos Laguna': 1788,
#  'Málaga CF': 2109,
#  'Vitória': 1408,
#  'Çaykur Rizespor': 2007,
#  'U.N.A.M.': 1932,
#  'Nottingham Forest': 2116,
#  'Royal Antwerp FC': 1743,
#  'Club Tijuana': 1829,
#  'Sport Club do Recife': 1388,
#  'Real Salt Lake': 1983,
#  'AZ Alkmaar': 2100,
#  'SK Slavia Praha': 1923,
#  'Willem II': 1828,
#  'Middlesbrough': 2040,
#  'Dinamo Zagreb': 1965,
#  'Club Atlas': 1891,
#  'Granada CF': 1934,
#  'Sydney FC': 1568,
#  'Sporting Kansas City': 1826,
#  'SV Zulte-Waregem': 1744,
#  'Philadelphia Union': 1912,
#  'Real Oviedo': 2044,
#  'Pachuca': 1942,
#  'Boavista FC': 1850,
#  'Atiker Konyaspor': 1882,
#  'Kaizer Chiefs': 1803,
#  'GD Chaves': 1762,
#  'Palermo': 2039,
#  'Atlético Nacional': 1859,
#  'Puebla FC': 1957,
#  'Perth Glory': 1592,
#  'Panathinaikos FC': 1881,
#  'FC Sion': 1744,
#  'Vitória de Setúbal': 1929,
#  'New York Red Bulls': 1935,
#  'Al Shabab': 1897,
#  'Monarcas Morelia': 1856,
#  'Albacete BP': 1979,
#  'Rangers FC': 1943,
#  'Sparta Praha': 1894,
#  'Legia Warszawa': 1840,
#  'Urawa Red Diamonds': 1766,
#  'Rosario Central': 1870,
#  'Stade de Reims': 1954,
#  'ADO Den Haag': 1867,
#  'Chapecoense': 1395,
#  'FC Midtjylland': 1791,
#  'San Jose Earthquakes': 1709,
#  'Belgrano de Córdoba': 1760,
#  'Brescia': 1974,
#  'Kashima Antlers': 1959,
#  'CD Everton de Viña del Mar': 1719,
#  'Fortuna Düsseldorf': 2258,
#  'SD Huesca': 2060,
#  'Preston North End': 1920,
#  'Club Atlético Talleres': 1844,
#  'Benevento': 1711,
#  'Vitesse': 1917,
#  'Gimnasia y Esgrima La Plata': 1828,
#  'Houston Dynamo': 1961,
#  'Club Necaxa': 1942,
#  'Norwich City': 2069,
#  'Holstein Kiel': 1888,
#  'Ettifaq FC': 1864,
#  'Kayserispor': 1717,
#  '1. FC Heidenheim 1846': 1841,
#  'Brentford': 1982,
#  'Yeni Malatyaspor': 1967,
#  'Lobos BUAP': 1782,
#  'Bursaspor': 2029,
#  'Ceará Sporting Club': 1354,
#  'Sheffield United': 2000,
#  'FC Ingolstadt 04': 1993,
#  'Estudiantes de La Plata': 1863,
#  'AIK': 1757,
#  'Queens Park Rangers': 1986,
#  'Suwon Samsung Bluewings': 1850,
#  'Heart of Midlothian': 1775,
#  'Reading': 2024,
#  'FC Dallas': 1898,
#  'Heracles Almelo': 1900,
#  'Venezia FC': 1831,
#  'CD Lugo': 2008,
#  'Henan Jianye FC': 1705,
#  'Orlando City SC': 1975,
#  'CA Osasuna': 1712,
#  'NAC Breda': 1932,
#  'Livorno': 1911,
#  'Universidad de Chile': 1922,
#  'Brøndby IF': 1761,
#  'Aberdeen': 1737,
#  'Defensa y Justicia': 1890,
#  'Atlético Tucumán': 1891,
#  'Blackburn Rovers': 1961,
#  'SV Darmstadt 98': 1806,
#  'Moreirense FC': 1728,
#  'Sanfrecce Hiroshima': 1667,
#  'CD Numancia': 1888,
#  'KV Oostende': 1748,
#  'FC Utrecht': 1780,
#  'Vancouver Whitecaps FC': 1786,
#  'Odense Boldklub': 1711,
#  'SC Heerenveen': 1812,
#  'Racing Club de Lens': 1958,
#  'Independiente Santa Fe': 1883,
#  'Sporting de Charleroi': 1878,
#  'Millonarios FC': 1880,
#  'Sheffield Wednesday': 2039,
#  'Perugia': 1701,
#  'Daegu FC': 1712,
#  'Vélez Sarsfield': 1827,
#  'Grasshopper Club Zürich': 1705,
#  'Sivasspor': 1808,
#  'Nîmes Olympique': 1843,
#  'Rosenborg BK': 1730,
#  'SK Sturm Graz': 1628,
#  'FC Metz': 1777,
#  'CD Universidad de Concepción': 1795,
#  'Hellas Verona': 1960,
#  'Brisbane Roar': 1461,
#  'CD Feirense': 1781,
#  'Hull City': 1986,
#  'Waasland-Beveren': 1812,
#  'Neuchâtel Xamax': 1654,
#  'Real Zaragoza': 2039,
#  'CD Aves': 1917,
#  'Millwall': 1959,
#  'Unión de Santa Fe': 1848,
#  'KAS Eupen': 1865,
#  'Cádiz CF': 2013,
#  'FC Tokyo': 1905,
#  'CD Tenerife': 2019,
#  '1. FC Union Berlin': 1913,
#  'Al Fayha': 1781,
#  'AJ Auxerre': 1790,
#  'Patriotas Boyacá FC': 1798,
#  'Molde FK': 1699,
#  'Bristol City': 2002,
#  'CD Nacional': 1776,
#  'Sporting Lokeren': 1884,
#  'FC St. Pauli': 1998,
#  'Deportes Iquique': 1779,
#  'Al Qadisiyah': 1879,
#  'Atlético Bucaramanga': 1797,
#  'Club Atlético Tigre': 1879,
#  'FK Austria Wien': 1771,
#  'Patronato': 1824,
#  'Malmö FF': 1795,
#  'Kashiwa Reysol': 1781,
#  'US Cremonese': 1664,
#  'VfL Bochum 1848': 1739,
#  'SK Rapid Wien': 1806,
#  'KSV Cercle Brugge': 1848,
#  'Rionegro Águilas': 1833,
#  'Gimnàstic de Tarragona': 2010,
#  'Lecce': 1871,
#  'Santa Clara': 1757,
#  'BK Häcken': 1677,
#  'New England Revolution': 1746,
#  'Orlando Pirates': 1857,
#  'Atlético Huila': 1711,
#  'Western Sydney Wanderers': 1546,
#  'Kalmar FF': 1680,
#  'Independiente Medellín': 1784,
#  'Fortuna Sittard': 1771,
#  'Lech Poznań': 1763,
#  'Djurgårdens IF': 1591,
#  'CF Reus Deportiu': 1826,
#  'SK Brann': 1721,
#  'Ulsan Hyundai FC': 1845,
#  'Sint-Truidense VV': 1888,
#  'Carpi': 1910,
#  'Al Fateh': 1708,
#  'Royal Excel Mouscron': 1813,
#  'AC Ajaccio': 1496,
#  'PEC Zwolle': 1773,
#  'Sunderland': 1816,
#  'Club Atlético Aldosivi': 1847,
#  'US Salernitana 1919': 1888,
#  'FC Lorient': 1913,
#  'Argentinos Juniors': 1810,
#  'AD Alcorcón': 1955,
#  'Crotone': 1591,
#  'Excelsior': 1688,
#  'KV Kortrijk': 1882,
#  'IFK Norrköping': 1545,
#  'Adelaide United': 1535,
#  'FC St. Gallen': 1580,
#  'Tiburones Rojos de Veracruz': 1867,
#  'CD Palestino': 1827,
#  'Jeju United FC': 1815,
#  'Deportes Tolima': 1842,
#  'Jeonbuk Hyundai Motors': 1872,
#  'Birmingham City': 2008,
#  'América de Cali': 1805,
#  'La Equidad': 1788,
#  'Spezia': 1824,
#  'Aalborg BK': 1675,
#  'Le Havre AC': 1926,
#  'Górnik Zabrze': 1658,
#  'Central Coast Mariners': 1531,
#  'Wigan Athletic': 1997,
#  'Jagiellonia Białystok': 1734,
#  'Cittadella': 1881,
#  'Hibernian': 1620,
#  'FC Lugano': 1690,
#  'San Martín de San Juan': 1820,
#  'Strømsgodset IF': 1519,
#  'Júbilo Iwata': 1826,
#  "Newell's Old Boys": 1860,
#  'Al Faisaly': 1887,
#  'Colorado Rapids': 1524,
#  'IF Elfsborg': 1701,
#  'SV Sandhausen': 1955,
#  'Al Batin': 1795,
#  'Stade Brestois 29': 1638,
#  'UD Almería': 1970,
#  'Gyeongnam FC': 1740,
#  'Yokohama F. Marinos': 1846,
#  'Kilmarnock': 1759,
#  'Pescara': 1844,
#  'Newcastle Jets': 1508,
#  'Córdoba CF': 1709,
#  'RCD Mallorca': 1828,
#  'Hammarby IF': 1721,
#  'Cerezo Osaka': 1931,
#  'KFC Uerdingen 05': 1787,
#  'Shimizu S-Pulse': 1885,
#  'MSV Duisburg': 1728,
#  'Os Belenenses': 1630,
#  'DSC Arminia Bielefeld': 1867,
#  'Ipswich Town': 1977,
#  'FC Seoul': 1838,
#  'Lechia Gdańsk': 1735,
#  'Gamba Osaka': 1834,
#  'CF Rayo Majadahonda': 1722,
#  'LASK Linz': 1513,
#  'Bolton Wanderers': 1989,
#  'Al Raed': 1854,
#  'Extremadura UD': 1962,
#  'SC Paderborn 07': 1912,
#  'Wellington Phoenix': 1306,
#  'Unión Española': 1763,
#  'Alianza Petrolera': 1786,
#  'Cracovia': 1674,
#  'Gangwon FC': 1809,
#  'Elche CF': 1718,
#  'ESTAC Troyes': 1999,
#  'AS Béziers': 1613,
#  'La Berrichonne de Châteauroux': 1494,
#  'Clermont Foot 63': 1605,
#  '1. FC Magdeburg': 1706,
#  'Pohang Steelers': 1731,
#  'Örebro SK': 1633,
#  'Arka Gdynia': 1677,
#  'SG Dynamo Dresden': 1849,
#  'SpVgg Greuther Fürth': 1840,
#  'CD Huachipato': 1656,
#  'Wisła Kraków': 1624,
#  'Stabæk Fotball': 1642,
#  'Eintracht Braunschweig': 1754,
#  'Valenciennes FC': 1832,
#  'FC Thun': 1585,
#  'San Luis de Quillota': 1760,
#  ' SSV Jahn Regensburg': 1902,
#  'Cosenza': 1894,
#  'FC Nordsjælland': 1646,
#  'FC Erzgebirge Aue': 1881,
#  'Jeonnam Dragons': 1796,
#  'Wolfsberger AC': 1600,
#  'Chamois Niortais Football Club': 1764,
#  'Club Deportes Temuco': 1759,
#  'AS Nancy Lorraine': 1940,
#  'Red Star FC': 1787,
#  'Al Hazem': 1847,
#  'Pogoń Szczecin': 1670,
#  'Charlton Athletic': 1778,
#  'Grenoble Foot 38': 1677,
#  'FC Hansa Rostock': 1576,
#  'San Martin de Tucumán': 1830,
#  'Incheon United FC': 1768,
#  'Śląsk Wrocław': 1555,
#  'GFC Ajaccio': 1439,
#  '1. FC Kaiserslautern': 1648,
#  'Deportivo Pasto': 1779,
#  'Lincoln City': 1697,
#  'Motherwell': 1742,
#  'Rotherham United': 1681,
#  'Burton Albion': 1727,
#  'Wisła Płock': 1587,
#  'FC Wacker Innsbruck': 1674,
#  'Peterborough United': 1659,
#  'Ascoli': 1939,
#  'FC Zürich': 1705,
#  'Fleetwood Town': 1741,
#  'Padova': 1955,
#  'FC Sochaux-Montbéliard': 1754,
#  'SV Wehen Wiesbaden': 1559,
#  'Unión La Calera': 1727,
#  'Scunthorpe United': 1673,
#  "CD O'Higgins": 1782,
#  'CD Antofagasta': 1789,
#  'Plymouth Argyle': 1772,
#  'Aarhus GF': 1658,
#  'Lillestrøm SK': 1474,
#  'Karlsruher SC': 1771,
#  'GIF Sundsvall': 1418,
#  'FC Emmen': 1861,
#  'Barnsley': 1731,
#  'Audax Italiano': 1788,
#  'V-Varen Nagasaki': 1810,
#  'Paris FC': 1595,
#  'SpVgg Unterhaching': 1596,
#  'Hobro IK': 1534,
#  'De Graafschap': 1914,
#  'Hokkaido Consadole Sapporo': 1780,
#  'Tromsø IL': 1254,
#  'FC Luzern': 1719,
#  'FK Haugesund': 1364,
#  'Zagłębie Lubin': 1691,
#  'VfR Aalen': 1500,
#  'Dundalk': 1420,
#  'Oxford United': 1748,
#  'Piast Gliwice': 1703,
#  'Ohod Club': 1525,
#  'Östersunds FK': 1398,
#  'Vegalta Sendai': 1677,
#  'Crawley Town': 1450,
#  'FC Admira Wacker Mödling': 1679,
#  'Vålerenga Fotball': 1606,
#  'Dundee FC': 1663,
#  'Portsmouth': 1789,
#  'Envigado FC': 1716,
#  'Miedź Legnica': 1683,
#  'Odds BK': 1432,
#  'SC Fortuna Köln': 1624,
#  'US Orléans Loiret Football': 1580,
#  'Sarpsborg 08 FF': 1632,
#  'Jaguares de Córdoba': 1758,
#  'Bradford City': 1746,
#  'Accrington Stanley': 1713,
#  'St. Johnstone FC': 1670,
#  'Boyacá Chicó FC': 1680,
#  'Luton Town': 1562,
#  'SV Mattersburg': 1696,
#  'Kristiansund BK': 1505,
#  'Sangju Sangmu FC': 1717,
#  'Rochdale': 1747,
#  'Walsall': 1711,
#  'Korona Kielce': 1657,
#  'Shonan Bellmare': 1818,
#  'FC Würzburger Kickers': 1682,
#  'FSV Zwickau': 1574,
#  'St. Mirren': 1632,
#  'AC Horsens': 1516,
#  'Esbjerg fB': 1501,
#  'HJK Helsinki': 1541,
#  'Southend United': 1771,
#  'Bristol Rovers': 1715,
#  'Hamilton Academical FC': 1650,
#  'TSV 1860 München': 1736,
#  'Curicó Unido': 1751,
#  'SCR Altach': 1640,
#  'Ranheim Fotball': 1467,
#  'Stevenage': 1623,
#  'SG Sonnenhof Großaspach': 1507,
#  'Oldham Athletic': 1506,
#  'Milton Keynes Dons': 1742,
#  'FK Bodø/Glimt': 1636,
#  'SC Preußen Münster': 1675,
#  'Wycombe Wanderers': 1593,
#  'Vejle Boldklub': 1626,
#  'Bury': 1724,
#  'Randers FC': 1538,
#  'VfL Osnabrück': 1614,
#  'SønderjyskE': 1629,
#  'IFK Göteborg': 1396,
#  'Mansfield Town': 1723,
#  'Coventry City': 1730,
#  'Waterford FC': 1430,
#  'Shrewsbury': 1657,
#  'IK Start': 1496,
#  'Gillingham': 1691,
#  'FC Energie Cottbus': 1731,
#  'FC Carl Zeiss Jena': 1724,
#  'Hallescher FC': 1548,
#  'SV Meppen': 1724,
#  'AFC Wimbledon': 1572,
#  'Blackpool': 1719,
#  'Doncaster Rovers': 1724,
#  'Sandefjord Fotball': 1459,
#  'VfL Sportfreunde Lotte': 1734,
#  'Cheltenham Town': 1448,
#  'IK Sirius': 1660,
#  'Vendsyssel FF': 1643,
#  'Swindon Town': 1537,
#  'Notts County': 1709,
#  'SKN St. Pölten': 1665,
#  'Exeter City': 1679,
#  'Northampton Town': 1647,
#  'Shamrock Rovers': 1322,
#  'Colchester United': 1700,
#  'Livingston FC': 1684,
#  'TSV Hartberg': 1579,
#  'Tranmere Rovers': 1630,
#  'Cambridge United': 1594,
#  'Grimsby Town': 1487,
#  'Port Vale': 1571,
#  'Itagüí Leones FC': 1702,
#  'Forest Green Rovers': 1474,
#  'Dalkurd FF': 1255,
#  'Zagłębie Sosnowiec': 1519,
#  'Carlisle United': 1472,
#  'Trelleborgs FF': 1613,
#  "St. Patrick's Athletic": 1329,
#  'Morecambe': 1596,
#  'Cork City': 1459,
#  'IF Brommapojkarna': 1556,
#  'Crewe Alexandra': 1590,
#  'Yeovil Town': 1690,
#  'Bohemian FC': 1375,
#  'Macclesfield Town': 1527,
#  'Newport County': 1527,
#  'Sligo Rovers': 1076,
#  'Derry City': 1004,
#  'Limerick FC': 1036,
#  'Bray Wanderers': 1234}

# %%
df_bcp = pd.DataFrame.from_dict(best_dict , orient = 'index')

# %%
df_bcp.rename(columns={list(df_bcp)[0]:'skor'}, inplace = True)
df_bcp.head()
# Out:
#                    skor
# Real Madrid        2582
# FC Barcelona       2575
# Manchester United  2549
# Chelsea            2534
# Manchester City    2532

# %%
df_bcp['skor'].nlargest(20).plot(kind = 'bar')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# Body Type                   18159 non-null object
# Real Face                   18159 non-null object
# Position                    18147 non-null object
# Jersey Number               18147 non-null float64
# Joined                      16654 non-null object
# Loaned From                 1264 non-null object
# Contract Valid Until        17918 non-null object
# Height                      18159 non-null object
# Weight                      18159 non-null object
# LS                          16122 non-null object
# ST                          16122 non-null object
# RS                          16122 non-null object
# LW                          16122 non-null object
# LF                          16122 non-null object
# CF                          16122 non-null object
# RF                          16122 non-null object
# RW                          16122 non-null object
# LAM                         16122 non-null object
# CAM                         16122 non-null object
# RAM                         16122 non-null object
# LM                          16122 non-null object
# LCM                         16122 non-null object
# CM                          16122 non-null object
# RCM                         16122 non-null object
# RM                          16122 non-null object
# LWB                         16122 non-null object
# LDM                         16122 non-null object
# CDM                         16122 non-null object
# RDM                         16122 non-null object
# RWB                         16122 non-null object
# LB                          16122 non-null object
# LCB                         16122 non-null object
# CB                          16122 non-null object
# RCB                         16122 non-null object
# RB                          16122 non-null object
# Crossing                    18159 non-null float64
# Finishing                   18159 non-null float64
# HeadingAccuracy             18159 non-null float64
# ShortPassing                18159 non-null float64
# Volleys                     18159 non-null float64
# Dribbling                   18159 non-null float64
# Curve                       18159 non-null float64
# FKAccuracy                  18159 non-null float64
# LongPassing                 18159 non-null float64
# BallControl                 18159 non-null float64
# Acceleration                18159 non-null float64
# SprintSpeed                 18159 non-null float64
# Agility                     18159 non-null float64
# Reactions                   18159 non-null float64
# Balance                     18159 non-null float64
# ShotPower                   18159 non-null float64
# Jumping                     18159 non-null float64
# Stamina                     18159 non-null float64
# Strength                    18159 non-null float64
# LongShots                   18159 non-null float64
# Aggression                  18159 non-null float64
# Interceptions               18159 non-null float64
# Positioning                 18159 non-null float64
# Vision                      18159 non-null float64
# Penalties                   18159 non-null float64
# Composure                   18159 non-null float64
# Marking                     18159 non-null float64
# StandingTackle              18159 non-null float64
# SlidingTackle               18159 non-null float64
# GKDiving                    18159 non-null float64
# GKHandling                  18159 non-null float64
# GKKicking                   18159 non-null float64
# GKPositioning               18159 non-null float64
# GKReflexes                  18159 non-null float64
# Release Clause              16643 non-null object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
data.sort_values(by = 'ShotPower' , ascending = False)[['Name','Club','Age','ShotPower']].head(5)
# Out:
#                    Name                           Club  Age  ShotPower
# 1     Cristiano Ronaldo                       Juventus   33       95.0
# 378                Hulk               Shanghai SIPG FC   31       94.0
# 1348          F. Guarín  Shanghai Greenland Shenhua FC   32       93.0
# 890         L. Podolski                    Vissel Kobe   33       92.0
# 36              G. Bale                    Real Madrid   28       92.0

# %%
data.sort_values(by= 'GKPositioning', ascending = False)[['Name','Club','Age','GKPositioning']].head(5)
# Out:
#              Name                 Club  Age  GKPositioning
# 41      G. Buffon  Paris Saint-Germain   40           90.0
# 40  S. Handanovič                Inter   33           89.0
# 3          De Gea    Manchester United   27           88.0
# 9        J. Oblak      Atlético Madrid   25           88.0
# 22       M. Neuer    FC Bayern München   32           87.0

# %%
data.sort_values(by= 'Finishing', ascending = False)[['Name','Club','Age','Finishing']].head(5)
# Out:
#                  Name               Club  Age  Finishing
# 0            L. Messi       FC Barcelona   31       95.0
# 1   Cristiano Ronaldo           Juventus   33       94.0
# 16            H. Kane  Tottenham Hotspur   24       94.0
# 23          S. Agüero    Manchester City   30       93.0
# 7           L. Suárez       FC Barcelona   31       93.0
